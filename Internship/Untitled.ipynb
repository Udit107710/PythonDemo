# %%
import pickle

# %%
with open('friend_graph.pickle','rb') as file:
    bingo = pickle.load(file)

# %%
for k,v in bingo.items():
    print(k,v)
# Out:
# kounirauthan18 ['hacker107710', 'anmol.pandit.12', 'arunabh.srivastava.12', 'M2MovieOfficial/', 'CrimePetrolShow/', 'abhishek.chauhan.00003', 'komal.chandola.94', '100004879458392', 'arpit.upreti', 'paarth.guide', 'bumbleb7599', 'mehul.uniyal', 'kshitij.shishodia', 'pihu.aggarwal.9465', 'geetika.pathak.90', 'ymalviya1', 'ritika.rawat2017', '100004648056127', 'rajpreetsrivastav.2000', 'vedansh.bindal', 'srishti.vats.18', 'JayShettyIW/', '100011528358205', '2foreignersinbollywood/', 'DestinationAmerica/', 'chiragarg.786', 'kaushik.moitra.3', 'nabh.gautam', 'aakriti.arora.73550', '100009290174094', 'cherry.sen', '100008539390344', 'ankitasingh7299', 'singh.shivangi.7564', '100011164786741', 'hardikrajvanshi007', 'shivani.kulasari', 'sriti.atharwee', 'ujjwal.joshi.9400', 'stuti.pokhriyal', 'vidhi.guglani.1', 'aniket.singh.5680899', 'akshat.khare.71', 'vikrant.rawat.167', 'rick.chakravorty.79', '100007259047475', 'able.alex', 'srishty.chandan.5', 'siddd.o1', 'anushree.datta.505', 'naveena
# ...
